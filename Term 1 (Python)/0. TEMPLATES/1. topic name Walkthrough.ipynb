# %% [markdown]
# # Example 1

# %% [markdown]
# Short explanation

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# # Example 2

# %% [markdown]
# Before running the code, predict the output of the code!

# %%
print('hi')
# Out:
# hi

# %% [markdown]
# Why does it print 'hi' and not 'bye'?

# %% [markdown]
# Answer:
