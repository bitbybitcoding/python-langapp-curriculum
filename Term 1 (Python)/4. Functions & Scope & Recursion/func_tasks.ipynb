# %% [markdown]
# #Micro-challenge 1: Create functions for add, subtract, multiply

# %% [markdown]
# 1. Addition function

# %%
#code
# Out:
# 5

# %% [markdown]
# 2. Subtract function

# %%
#code

# %% [markdown]
# 3. Multiply function

# %%
#code

# %% [markdown]
# #Micro-challenge 2: Create function that draws a shape of specified size/color
# The function should take 2 parameters - size and color, and draw the shape using the *turtle* library.

# %%
# !pip install ColabTurtlePLus

# %%
from ColabTurtlePlus.Turtle import *
clearscreen()

def draw_shape(sides, size, colour):
  t = Turtle()

  return

# %% [markdown]
# # Micro-challenge 3: Recursion

# %% [markdown]
# 1a. Create a simple function that uses recursion to calculate *n!*. The function should take one parameter `n`.

# %%
#code

# %% [markdown]
# 1b. Create a function that takes a nested list and returns a flattened list

# %% [markdown]
# Eg: `[1, [2, 3], [4, [5, 6]]]` -> `[1,2,3,4,5,6]`

# %%
#code

# %% [markdown]
# # Collaborative Challenge: Character status tracker

# %% [markdown]
# You need to create a tracking system for a game that can track and update the health of a player. We will also design a simple static health bar for the player.

# %% [markdown]
# # Requirements
# 1. `take_damage(health, damage)`, this function takes the current health of the plater and subtracts the damage value from the health value. *MAKE SURE THE FUNCTION DOES NOT RETURN NEGATIVE VALUES*
# 2. `level_up(experience, level, level_up_threshold)`, this function updates the level whenever the experience exceeds the *level_up_threshold*
# 3. `draw_health_bar(health, max_health)` this function uses the *turtle* library to draw a statis health bar for the player.

# %% [markdown]
# #Preset values
# - `level_up_threshold = 150`
# - `if health > 50%` health bar should be green
# - `if health > 20%` health bar should be orange
# - `if health < 20%` health bar should be red

# %%
clearscreen()

def draw_rectangle(t, width, height, fill_color=None, outline_color="black"):
    t = Turtle()
    t.color(outline_color, fill_color if fill_color else outline_color)

    t.done()

def draw_health_bar(health_percent):
    return

draw_health_bar(0.2)

# %% [markdown]
# #Homework
#
# 1.   List item
# 2.   List item

# %% [markdown]
# ## Fix-it! 🔨
# The following code has many errors, can you spot and fix them?

# %%
numbers = [3, 7, 2, 12, 5]
def find_largest(nums):
    largest = 0

    for n in nums:
        if n > largest:
            largest = n

def show_result():
    find_largest(numbers)
    print("Largest number:", largest)

show_result()

# %% [markdown]
# # Predict! 🔮

# %% [markdown]
# Don't run this code in a cell yet! Look at the code and write down what you think the output will be for each print statement.

# %%
def add(a, b):
    result = a + b
    print("Inside function:", result)
    return result

value = add(3, 4)
print("Outside function:", value)

# %%
def f1(x):
    return x * 2

def f2(num):
    num = f1(num)
    num = num + 3
    return num

print(f2(f1(5)))

# %%
x = 10

def change():
    x = 5
    print("Inside:", x)

change()
print("Outside:", x)

# %% [markdown]
# ## Fill-in-the-blanks! ✏️

# %%
#the final function that takes a list and returns how many numbers in the list are even

def is_even(n):
    _______ n % _______ == 0

numbers = [3, 6, 8, 11]

def counter______
  count = 0

  for n in numbers:
      if _______(n):
          count = count + 1

  return _________

print("Even numbers:", count)
