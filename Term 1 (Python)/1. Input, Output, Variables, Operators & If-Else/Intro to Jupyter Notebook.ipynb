# %%
# You'll be spending a lot of time on Jupyter notebooks. These are places for you
# to write and run code neatly. They have many usecases, including in data
# science, machine learning and AI, but in this course, they'll make amazing
# places for you to have your very first taste of Python.


# First, this is a comment. It does nothing.
'''
This is also
a comment, and it also
does nothing.
'''

# But this:
print("Hello world")
# does something.

#Why?
# Out:
# Hello world

# %%
# To run code in Jupyter Notebook, simply click the play button at the top left
# corner of every cell. It's that convenient!

# Try it:
print("Did you click the right button?")
# Out:
# Did you click the right button?

# %%
# You can interact with your code sometimes

# Try this:
# Once an entry field opens, type your name, then hit 'enter'!

a = input("What's your name? ")
print(f"Hi, {a}")
# Out:
# What's your name? mary
# Hi, mary

# %%
# Got it?

# Nice!

# Let's hit the road and tackle Python, bit by bit!
