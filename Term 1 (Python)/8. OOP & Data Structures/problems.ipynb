# %% [markdown]
# # Collaborative Challenge 🚀: "The Survival Game Engine"
#
# In this activity, your team will build the core logic for a survival game using Object-Oriented Programming (OOP). You will create the game controller, a base character class, and specialized warrior subclasses.

# %% [markdown]
# ## Part 1: The Game Controller 🎮
#
# First, define a class called `game`. This will manage the overall state of your session.
#
# 1. **Constructor**: Initialize `self.state` to `0` and print `"Game initialised!"`.
# 2. **set_state**: Create a method that takes `state` as an argument, updates `self.state`, and returns the new value.
# 3. **get_state**: Create a method that returns the current value of `self.state`.
# 4. **check_win**: Create a method that returns `False` if `self.state` is `0`, otherwise returns `True`.

# %%
# Write your game class here
class game:
    def __init__(self):
        pass # Replace with your code

# %% [markdown]
# ## Part 2: The Base Character 👤
#
# Now, let's create the `character` class. Every player in your game will start with these basic attributes and abilities.
#
# 1. **Attributes**: Initialize `self.health` to `100` and `self.weapons` to an empty list `[]`.
# 2. **take_damage**: Subtract a damage value from health.
#     - If health > 0: Print `"Character took damage"` and return health.
#     - Else: Print `"Character dead. Game Over"` and return `None`.
# 3. **drink_potion**: Add a heal value to health (max 100).
#     - If health reaches 100: Print `"Hero health full!"`.
#     - Else: Print the new health value.
# 4. **gain_weapon**: Check if the input is a string, append it to `self.weapons`, print `"Weapon gained"`, and return the list.

# %%
# Write your character class here
class character:
    def __init__(self):
        pass # Replace with your code

# %% [markdown]
# ## Part 3: Specialized Warriors ⚔️
#
# Create a `warrior` class that inherits from `character`. Warriors have names and belong to clans.
#
# 1. **Inheritance**: Use `super()` to call the character constructor.
# 2. **Attributes**: Take `name` as an argument and initialize `self.clan` as an empty string.
# 3. **Methods**:
#     - `join_clan(clan)`: Updates and returns the clan name.
#     - `find_clan()`: Returns the current clan name.

# %%
# Write your warrior class here
class warrior(character):
    def __init__(self, name):
        pass # Replace with your code

# %% [markdown]
# ## Final Mission: Put it all together! 🚀
#
# Use the cell below to simulate a small adventure. Create a warrior, take damage, find a weapon, and check the game state.

# %%
# Test your engine
my_game = game()
hero = warrior("Thor")

print(f"Hero: {hero.name}, Health: {hero.health}")
hero.take_damage(30)
hero.gain_weapon("Mjolnir")
my_game.set_state(1)

if my_game.check_win():
    print("Mission Accomplished!")

# %% [markdown]
# # Week 8 Homework – Object-Oriented Programming & Data Structures
#
# Welcome to your Week 8 homework!
# This notebook will help you practice:
#
# - Designing your own **classes**
# - Creating and using **objects**
# - Using **inheritance** (`class Child(Parent):`)
# - Building simple **linked lists** and **binary trees**
#
# You do **not** need to finish everything in one sitting.
# Do as much as you can, and have fun experimenting!

# %% [markdown]
# ## 0. Warm-Up Story: You Are The Game Engine
#
# Imagine you are building a game.
# Everything in your game – player, enemies, items, bullets, trees, NPCs – can be modeled as **objects**.
#
# In this homework, you will:
#
# 1. Create game-style classes (like `Character`, `Wizard`, `Enemy`)
# 2. Use inheritance so different characters share code
# 3. Build your own mini **linked list** to store a sequence of actions
# 4. Build a simple **binary tree** of game locations or decisions

# %%
# You might find these useful later.
# Feel free to add more imports if you need them.
from typing import Optional, List

# %% [markdown]
# ## 1. Game Characters – Basic Class Design
#
# **Goal:** Practice defining a simple class with attributes and methods.
#
# Create a `Character` class for a text-based game with:
#
# - Attributes:
#   - `name` (string)
#   - `health` (int)
#   - `attack_power` (int)
# - Methods:
#   - `is_alive()` → returns `True` if health > 0, else `False`
#   - `take_damage(amount)` → subtracts `amount` from health (but not below 0)
#   - `attack(other_character)` → prints an attack message and reduces the other character's health by `self.attack_power`
#
# Then:
#
# 1. Create two characters (for example, `hero` and `goblin`).
# 2. Make them attack each other a few times.
# 3. Print their health after each attack and check who is still alive.

# %%
# TODO: Implement the Character class and demo here.

class Character:
    # Your code here
    pass

# Demo:
# 1. Create at least two characters
# 2. Make them attack each other
# 3. Print their health and alive status

# %% [markdown]
# ## 2. Level Up: Inheritance
#
# **Goal:** Use inheritance to create more specific types of characters.
#
# You already have a `Character` base class.
# Now create two subclasses:
#
# 1. `Wizard(Character)`
#    - Extra attribute: `mana` (int)
#    - New method: `cast_spell(other_character, cost, damage)`
#      - Only works if `self.mana >= cost`
#      - Reduces `self.mana` by `cost`
#      - Reduces `other_character.health` by `damage`
# 2. `Tank(Character)`
#    - Extra attribute: `armor` (int)
#    - Override `take_damage(amount)` so that:
#      - Actual damage = max(0, `amount - armor`)
#      - Then subtract this from health
#
# Then:
#
# - Create a `Wizard` and a `Tank`.
# - Make them fight:
#   - Wizard sometimes uses `cast_spell`
#   - Tank sometimes uses normal `attack`
# - Print out what happens each turn.

# %%
# TODO: Implement Wizard and Tank subclasses here.

class Wizard(Character):
    # Your code here
    pass

class Tank(Character):
    # Your code here
    pass

# Demo battle between a Wizard and a Tank here.

# %% [markdown]
# ## 3. Inventory System – Objects Inside Objects
#
# **Goal:** Practice having objects that contain other objects (composition).
#
# Create two classes:
#
# 1. `Item`
#    - Attributes: `name` (str), `value` (int)
#    - `__str__` method that returns something like `"Sword (value: 100)"`
#
# 2. `Inventory`
#    - Attribute: `items` (a Python list of `Item` objects)
#    - Methods:
#      - `add_item(item)` → adds an `Item` to the list
#      - `total_value()` → returns the sum of values of all items
#      - `show_items()` → prints all items in a nice format
#
# Then:
#
# - Give your `Character` class an `inventory` attribute (an `Inventory` object).
# - Add some items to your hero’s inventory.
# - Show your hero’s inventory and its total value.

# %%
# TODO: Implement Item and Inventory, then integrate with Character.

class Item:
    # Your code here
    pass

class Inventory:
    # Your code here
    pass

# Update Character to include an inventory (if you want, you can redefine Character here).

# Demo:
# 1. Create a hero with an empty inventory
# 2. Add several items
# 3. Show items and total value

# %% [markdown]
# ## 4. Your First Linked List – Action Queue
#
# **Idea:** A **linked list** is a chain of nodes.
# Each node holds:
# - some `data`
# - a `next` pointer to the next node (or `None` if it is the last one)
#
# We’ll create a linked list to store a queue of **actions** a game character will take, in order.
# Example actions: `"move_left"`, `"jump"`, `"attack"`, `"heal"`.
#
# You will build:
#
# 1. A `Node` class
# 2. An `ActionList` class that behaves like a simple linked list

# %% [markdown]
# ### 4.1 Node Class
#
# Create a `Node` class with:
#
# - Attributes:
#   - `action` (string)
#   - `next` (another `Node` or `None`)
#
# ### 4.2 ActionList Class
#
# Create an `ActionList` class with:
#
# - Attribute:
#   - `head` (the first node, or `None` if empty)
#
# - Methods:
#   - `add_action(action)`
#     Adds a new action to the **end** of the list.
#   - `pop_action()`
#     Removes the **first** action from the list and returns it.
#     If list is empty, return `None`.
#   - `show_actions()`
#     Prints all actions in order, like:
#     `move_left -> jump -> attack -> None`
#
# Then:
#
# 1. Create an `ActionList`.
# 2. Add at least 4 actions.
# 3. Show the actions.
# 4. Pop actions one by one and print them.
# 5. Show the list after each pop.

# %%
# TODO: Implement Node and ActionList.

class Node:
    # Your code here
    pass

class ActionList:
    # Your code here
    pass

# Demo:
# 1. Create a list
# 2. Add actions
# 3. Show and pop them

# %% [markdown]
# ### 4.3 (Optional Challenge) Connect Character with ActionList
#
# If you feel confident, try this:
#
# - Give your `Character` an `action_list` attribute (an `ActionList`).
# - Add a method `plan_action(action)` that adds an action to the list.
# - Add a method `perform_next_action()` that:
#   - Pops the next action from the list
#   - Prints something like: `"Alice performs: move_left"`
#   - (Optional) Actually does something based on the action string
#
# Example usage:
#
# ```python
# hero.plan_action("move_left")
# hero.plan_action("attack")
# hero.perform_next_action()  # performs move_left
# hero.perform_next_action()  # performs attack

# %%
# Update your code above

# %% [markdown]
# ***
#
# ## Part 4 – Intro to Binary Trees
#
# ```markdown
# ## 5. Binary Tree – Game Map or Decision Tree
#
# A **binary tree** is made of nodes where each node has up to **two children**:
#
# - `left` child
# - `right` child
#
# Visual example:
#
#         Start
#       /     \
#     Forest Castle
#     / \     /    \
# Lake Cave Gate Throne
#
#
# We’ll create a tiny binary tree representing **locations** in a game world or **choices** in a story.

# %% [markdown]
# ### 5.1 TreeNode Class
#
# Create a `TreeNode` class with:
#
# - Attributes:
#   - `name` (string)
#   - `left` (TreeNode or None)
#   - `right` (TreeNode or None)
#
# Add a method:
#
# - `describe()`
#   Prints the node’s name and the names of its children (if they exist).
#   Example:
#   `"You are at: Start. Left: Forest, Right: Castle"`
#
# ### 5.2 Build a Small Map
#
# Manually build a tree like this:
#
# - Root: `"Start"`
#   - Left child: `"Forest"`
#     - Left: `"Lake"`
#     - Right: `"Cave"`
#   - Right child: `"Castle"`
#     - Left: `"Gate"`
#     - Right: `"Throne"`
#
# Then:
#
# 1. Print `describe()` for each node.
# 2. Starting from `"Start"`, simulate a path:
#    - For example: go left to `"Forest"`, then right to `"Cave"`.
#    - Print each step you take.

# %%
# TODO: Implement TreeNode and build the map.

class TreeNode:
    # Your code here
    pass

# Build the tree nodes here (Start, Forest, Castle, Lake, Cave, Gate, Throne)

# Demo:
# 1. Call describe() on several nodes
# 2. Simulate a path from Start

# %% [markdown]
# ### 5.3 (Optional Challenge) Tree Traversal
#
# Write a function `print_preorder(node)` that:
#
# 1. Prints the current node’s name.
# 2. Recursively visits the left child.
# 3. Recursively visits the right child.
#
# Call `print_preorder(root)` on your `"Start"` node.
#
# You should see all locations printed in a certain order (preorder traversal).

# %%
# TODO: Implement print_preorder(node) function.

def print_preorder(node):
    # Your code here
    pass

# Demo:
# Call print_preorder on your root node.

# %% [markdown]
# ## 6. Reflection (Short Answer)
#
# Answer these questions in this cell (in your own words):
#
# 1. What is one **advantage** of using classes and objects instead of just variables and functions?
# 2. How would you explain a **linked list** to a friend who only knows Python lists?
# 3. How would you explain a **binary tree** using a real-life analogy?
#
# You can write bullet points or short paragraphs. No need to be perfect – this is for you to think about how you understand OOP and data structures.
