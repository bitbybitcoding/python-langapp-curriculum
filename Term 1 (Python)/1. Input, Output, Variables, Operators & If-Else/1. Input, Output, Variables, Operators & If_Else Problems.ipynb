# %% [markdown]
# # Micro-challenge 1 🔍: The Character Card (Print & Variables)

# %% [markdown]
# You're building a character select screen for a new RPG.
#
# 1. Create the following variables:
#    - `character_name` → set it to your favourite game character's name (a string)
#    - `character_class` → set it to a class like `"Mage"`, `"Warrior"`, or `"Archer"` (a string)
#    - `level` → set it to any whole number (an int)
#    - `health` → set it to any decimal number (a float)

# %%
# write code here

# %% [markdown]
# 2. Use `print()` to display the character card in the following format:
# ```
# === CHARACTER CARD ===
# Name: <character_name>
# Class: <character_class>
# Level: <level>
# Health: <health>
# ```

# %%
# write code here

# %% [markdown]
# 3. Use `type()` to print the data type of each variable. Confirm that `character_name` is a `str`, `level` is an `int`, and `health` is a `float`.

# %%
# write code here

# %% [markdown]
# # Micro-challenge 2 🔍: The Potion Mixer (Input & Operators)

# %% [markdown]
# You run a potion shop and need a calculator to figure out prices.
#
# 1. Use `input()` to ask the user: `"How many potions do you want to buy? "`. Store it in a variable called `quantity`.
#
# *Remember: `input()` returns a string! You'll need to convert it.*

# %%
# write code here

# %% [markdown]
# 2. Each potion costs `15` gold. Calculate the `total_cost` and print it.
#
# For example: `"Total cost: 45 gold"`

# %%
# write code here

# %% [markdown]
# 3. The shop has a "Buy 3 get 1 free" deal. Use the `//` (floor division) and `%` (modulus) operators to calculate:
#    - How many **free** potions does the customer get?
#    - How many potions do they actually **pay for**?
#    - What is the **discounted total cost**?
#
# *Hint: If the customer buys 10 potions, they get 10 // 3 = 3 free ones, and pay for 10 - 3 = 7.*

# %%
# write code here

# %% [markdown]
# **Bonus Task**: Calculate and print how much gold the customer **saved** compared to the original total cost.

# %%
# write code here

# %% [markdown]
# # Micro-challenge 3 🔍: The Gatekeeper (If/Else)

# %% [markdown]
# You approach the entrance to the Dragon's Lair. The Gatekeeper will only let you in under certain conditions.
#
# 1. Use `input()` to ask the player for their `level` (convert to `int`).
# 2. Use `input()` to ask if they have a `dragon_permit` (the user should type `"yes"` or `"no"`).

# %%
# write code here

# %% [markdown]
# 3. Write an `if/elif/else` block with the following rules:
#    - If the player's level is **20 or above** AND they have a dragon permit → Print `"The gates open. Enter if you dare!"`
#    - Elif the player's level is **20 or above** but they do NOT have a permit → Print `"You're strong enough, but you need a Dragon Permit!"`
#    - Elif the player's level is **below 20** but they have a permit → Print `"You have the permit, but you need to reach Level 20!"`
#    - Else → Print `"You need both Level 20 and a Dragon Permit to enter."`
#
# *Hint: To check if the user typed `"yes"`, compare the `dragon_permit` variable using `==`.*

# %%
# write code here

# %% [markdown]
# # Collaborative Challenge 🚀: "The Adventure Decision Engine"

# %% [markdown]
# Your team is building a text-based adventure game! The player makes choices and the story changes depending on their decisions.
#
# Run the cell below to set up the starting scenario.

# %%
# Starting stats
gold = 50
health = 100
has_sword = False
has_shield = False

# %% [markdown]
# ## 🛠️ The Mission Requirements
#
# Write a script that does the following **in order**:
#
# 1. **Welcome the player**: Ask for their name using `input()`. Print a welcome message.
#
# 2. **The Shop**: Tell the player they have arrived at a shop. Display their current gold. A sword costs `30` gold and a shield costs `25` gold.
#    - Ask: `"Do you want to buy a Sword? (yes/no) "`
#      - If yes AND they have enough gold: subtract the cost, set `has_sword` to `True`, and print a success message.
#      - If yes but not enough gold: print `"Not enough gold!"`.
#    - Ask: `"Do you want to buy a Shield? (yes/no) "`
#      - Same logic as the sword.
#    - Print their updated `gold`, `has_sword`, and `has_shield`.
#
# 3. **The Crossroads**: The player reaches a fork in the road. Ask them to choose `"left"` or `"right"`.
#    - **Left path**: The player finds a healing spring! Add `25` to their health (but health should not go above `100`). Print the result.
#    - **Right path**: The player encounters a bandit!
#      - If `has_sword` is `True`: print `"You fight the bandit and win 20 gold!"` and add `20` gold.
#      - Else: print `"The bandit steals 15 gold!"` and subtract `15` gold.
#    - If neither `"left"` nor `"right"`: print `"You stand still, confused."`
#
# 4. **Final Stats**: Print the player's final `health`, `gold`, `has_sword`, and `has_shield`.

# %%
# write code here

# %% [markdown]
# ### **Bonus Task**
# What happens if the player types `"Left"` instead of `"left"`? Your code might not recognise it!
# Amend your code so that capitalization doesn't matter.
#
# *Hint: Look up the `.lower()` string method.*

# %% [markdown]
# # Homework

# %% [markdown]
# ## Fix-it! 🔨
# The following code has many errors, can you spot and fix them?

# %%
# The Goal: Get the player's name and age, then decide if they can enter the arena.

# 1. Get the player's name
player name = input("What is your name? ")

# 2. Get the player's age
age = input("How old are you? ")

# 3. Check if they are old enough (must be 13 or older)
if age >= 13
    print("Welcome to the Arena, "+ player_name)
else
    print("Sorry, you must be at least 13 to enter.")

# 4. Calculate how many years until they are 18
years_left = "18"- age
print("Years until you are 18: "+ years_left)

# %% [markdown]
# ## Predict! 🔮

# %% [markdown]
# Don't run this code in a cell yet! Look at the code and write down what you think the output will be for each print statement.

# %%
x = 10
y = 3
print(x // y)
print(x % y)
print(x ** y)
# Prediction:

# %%
hp = 50
shield = True
damage = 30

if shield:
    damage = damage // 2

hp = hp - damage
print(hp)
# Prediction:

# %%
a = "5"b = "10"print(a + b)
print(int(a) + int(b))
# Prediction:

# %% [markdown]
# ## Fill-in-the-blanks! ✏️

# %%
# Build a simple "Is it hot outside?"checker

# 1. Ask the user for the temperature (convert to int)
temp = _______(input("What is the temperature? "))

# 2. If temperature is above 35, print "It's scorching! Stay inside!"_______ temp > 35:
    print("It's scorching! Stay inside!")

# 3. Elif temperature is between 20 and 35 (inclusive), print "Nice weather!"_______ temp >= 20:
    print("Nice weather!")

# 4. Else, print "Brrr! It's cold!"_______:
    print("Brrr! It's cold!")

# %% [markdown]
# ## Be Creative! 💡
# Build a **"Would You Survive?"** quiz! Ask the user at least 3 questions (using `input`) and keep a running `score`.
#
# At the end, use `if/elif/else` to display a different survival message based on their score.
#
# For example:
# - 3/3 correct → `"You'd survive easily!"`
# - 2/3 correct → `"You'd survive... barely."`
# - 1/3 or less → `"You wouldn't make it. Try again!"`
#
# Use whatever theme you like — zombies, a desert island, outer space, the Hunger Games — get creative!

# %%
# write code here
